# %% [markdown]
# ## TASK 1 : STOCK PREDICTION

# %% [markdown]
# ## PURPOSE : To Predict the STOCK PRICE of a company using LSTM.

# %% [markdown]
# ## About the Dataset

# %% [markdown]
# ## Google Stock Price Prediction

# %% [markdown]
# This dataset contains historical data of Google's stock prices and related attributes.
# It consists of 14 columns and a smaller subset of 1257 rows.
# Each column represents a specific attribute, and each row contains the corresponding values for that attribute.

# %% [markdown]
# The columns in the dataset are as follows:
#
# 1.Symbol: The name of the company, which is GOOG in this case.
# 2.Date: The year and date of the stock data.
# 3.Close: The closing price of Google's stock on a particular day.
# 4.High: The highest value reached by Google's stock on the given day.
# 5.Low: The lowest value reached by Google's stock on the given day.
# 6.Open: The opening value of Google's stock on the given day.
# 7.Volume: The trading volume of Google's stock on the given day, i.e., the number of shares traded.
# 8.adjClose: The adjusted closing price of Google's stock, considering factors such as dividends and stock splits.
# 9.adjHigh: The adjusted highest value reached by Google's stock on the given day.
# 10.adjLow: The adjusted lowest value reached by Google's stock on the given day.
# 11.adjOpen: The adjusted opening value of Google's stock on the given day.
# 12.adjVolume: The adjusted trading volume of Google's stock on the given day, accounting for factors such as stock splits.
# 13.divCash: The amount of cash dividend paid out to shareholders on the given day.
# 14.splitFactor: The split factor, if any, applied to Google's stock on the given day. A split factor of 1 indicates no split.

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the Dataset
google_stock_data = pd.read_csv('GOOG.csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
# Showing inforamation about the dataset
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# Extracting required columns
google_stock_data = google_stock_data[['date','open','close']]
 # Selecting only date
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) 
# Setting date column as index
google_stock_data.set_index('date',drop=True,inplace=True) 
google_stock_data.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()

# %% [markdown]
# ## Data Pre-Processing

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %% [markdown]
# ## Train_Test_Split

# %%
 # Selecting 80 % for training and 20 % for testing
training_size = round(len(google_stock_data) * 0.80) 
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %% [markdown]
# ## Creating LSTM model

# %%
# !pip install keras
# Out:
# Collecting keras
#   Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 3.0 MB/s eta 0:00:00
# Installing collected packages: keras
# Successfully installed keras-2.14.0

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 6s 94ms/step - loss: 0.0087 - mean_absolute_error: 0.0669 - val_loss: 0.0146 - val_mean_absolute_error: 0.1040
# Epoch 2/80
# 30/30 [==============================] - 2s 63ms/step - loss: 9.8239e-04 - mean_absolute_error: 0.0245 - val_loss: 0.0037 - val_mean_absolute_error: 0.0482
# Epoch 3/80
# 30/30 [==============================] - 2s 63ms/step - loss: 5.9110e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0017 - val_mean_absolute_error: 0.0346
# Epoch 4/80
# 30/30 [==============================] - 2s 61ms/step - loss: 5.9109e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0028 - val_mean_absolute_error: 0.0422
# Epoch 5/80
# 30/30 [==============================] - 2s 62ms/step - loss: 5.3103e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0025 - val_mean_absolute_error: 0.0393
# Epoch 6/80
# 30/30 [==============================] - 2s 60ms/step - loss: 5.0429e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0017 - val_mean_absolute_error: 0.0333
# Epoch 7/80
# 30/30 [==============================] - 2s 58ms/step - loss: 5.1086e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0037 - val_mean_absolute_error: 0.0502
# Epoch 8/80
# 30/30 [==============================] - 2s 63ms/step - loss: 4.5920e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0033 - val_mean_absolute_error: 0.0463
# Epoch 9/80
# 30/30 [==============================] - 2s 54ms/step - loss: 4.5674e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0039 - val_mean_absolute_error: 0.0510
# Epoch 10/80
# 30/30 [==============================] - 2s 60ms/step - loss: 4.3961e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0031 - val_mean_absolute_error: 0.0452
# Epoch 11/80
# 30/30 [==============================] - 2s 58ms/step - loss: 3.6330e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0034 - val_mean_absolute_error: 0.0475
# Epoch 12/80
# 30/30 [==============================] - 2s 62ms/step - loss: 3.6360e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0045 - val_mean_absolute_error: 0.0563
# Epoch 13/80
# 30/30 [==============================] - 2s 62ms/step - loss: 3.5873e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0038 - val_mean_absolute_error: 0.0501
# Epoch 14/80
# 30/30 [==============================] - 2s 62ms/step - loss: 3.5584e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0039 - val_mean_absolute_error: 0.0506
# Epoch 15/80
# 30/30 [==============================] - 2s 59ms/step - loss: 3.6847e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0039 - val_mean_absolute_error: 0.0513
# Epoch 16/80
# 30/30 [==============================] - 2s 60ms/step - loss: 3.2687e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0034 - val_mean_absolute_error: 0.0463
# Epoch 17/80
# 30/30 [==============================] - 2s 61ms/step - loss: 3.1317e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0053 - val_mean_absolute_error: 0.0608
# Epoch 18/80
# 30/30 [==============================] - 2s 65ms/step - loss: 3.1786e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0046 - val_mean_absolute_error: 0.0551
# Epoch 19/80
# 30/30 [==============================] - 2s 56ms/step - loss: 3.4722e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0058 - val_mean_absolute_error: 0.0634
# Epoch 20/80
# 30/30 [==============================] - 2s 60ms/step - loss: 3.0137e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0048 - val_mean_absolute_error: 0.0573
# Epoch 21/80
# 30/30 [==============================] - 2s 65ms/step - loss: 2.9797e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0069 - val_mean_absolute_error: 0.0697
# Epoch 22/80
# 30/30 [==============================] - 2s 64ms/step - loss: 2.8101e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0049 - val_mean_absolute_error: 0.0560
# Epoch 23/80
# 30/30 [==============================] - 2s 62ms/step - loss: 2.8064e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0083 - val_mean_absolute_error: 0.0777
# Epoch 24/80
# 30/30 [==============================] - 2s 58ms/step - loss: 3.0548e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0061 - val_mean_absolute_error: 0.0644
# Epoch 25/80
# 30/30 [==============================] - 1s 49ms/step - loss: 3.0818e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0021 - val_mean_absolute_error: 0.0347
# Epoch 26/80
# 30/30 [==============================] - 2s 59ms/step - loss: 3.3681e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0032 - val_mean_absolute_error: 0.0435
# Epoch 27/80
# 30/30 [==============================] - 2s 65ms/step - loss: 3.0007e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0052 - val_mean_absolute_error: 0.0586
# Epoch 28/80
# 30/30 [==============================] - 1s 44ms/step - loss: 2.7439e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0050 - val_mean_absolute_error: 0.0564
# Epoch 29/80
# 30/30 [==============================] - 2s 61ms/step - loss: 2.7658e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0039 - val_mean_absolute_error: 0.0503
# Epoch 30/80
# 30/30 [==============================] - 2s 63ms/step - loss: 2.8784e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0039 - val_mean_absolute_error: 0.0496
# Epoch 31/80
# 30/30 [==============================] - 2s 61ms/step - loss: 2.7058e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0060 - val_mean_absolute_error: 0.0649
# Epoch 32/80
# 30/30 [==============================] - 2s 60ms/step - loss: 2.7213e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0066 - val_mean_absolute_error: 0.0669
# Epoch 33/80
# 30/30 [==============================] - 2s 55ms/step - loss: 2.7587e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0080 - val_mean_absolute_error: 0.0767
# Epoch 34/80
# 30/30 [==============================] - 2s 56ms/step - loss: 2.5296e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0035 - val_mean_absolute_error: 0.0459
# Epoch 35/80
# 30/30 [==============================] - 2s 56ms/step - loss: 2.3805e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0048 - val_mean_absolute_error: 0.0554
# Epoch 36/80
# 30/30 [==============================] - 2s 56ms/step - loss: 2.4038e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0063 - val_mean_absolute_error: 0.0663
# Epoch 37/80
# 30/30 [==============================] - 2s 55ms/step - loss: 2.3179e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0047 - val_mean_absolute_error: 0.0536
# Epoch 38/80
# 30/30 [==============================] - 2s 64ms/step - loss: 2.3283e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0073 - val_mean_absolute_error: 0.0707
# Epoch 39/80
# 30/30 [==============================] - 2s 63ms/step - loss: 2.2879e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0070 - val_mean_absolute_error: 0.0677
# Epoch 40/80
# 30/30 [==============================] - 2s 61ms/step - loss: 2.1753e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0034 - val_mean_absolute_error: 0.0445
# Epoch 41/80
# 30/30 [==============================] - 2s 63ms/step - loss: 2.4350e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0058 - val_mean_absolute_error: 0.0605
# Epoch 42/80
# 30/30 [==============================] - 2s 60ms/step - loss: 2.0830e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0047 - val_mean_absolute_error: 0.0514
# Epoch 43/80
# 30/30 [==============================] - 2s 62ms/step - loss: 2.1837e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0050 - val_mean_absolute_error: 0.0546
# Epoch 44/80
# 30/30 [==============================] - 2s 65ms/step - loss: 2.1399e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0055 - val_mean_absolute_error: 0.0571
# Epoch 45/80
# 30/30 [==============================] - 2s 54ms/step - loss: 2.0809e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0061 - val_mean_absolute_error: 0.0619
# Epoch 46/80
# 30/30 [==============================] - 2s 54ms/step - loss: 2.2037e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0062 - val_mean_absolute_error: 0.0624
# Epoch 47/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.9119e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0070 - val_mean_absolute_error: 0.0677
# Epoch 48/80
# 30/30 [==============================] - 2s 65ms/step - loss: 2.0471e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0059 - val_mean_absolute_error: 0.0613
# Epoch 49/80
# 30/30 [==============================] - 2s 63ms/step - loss: 2.0191e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0055 - val_mean_absolute_error: 0.0575
# Epoch 50/80
# 30/30 [==============================] - 2s 59ms/step - loss: 2.0614e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0050 - val_mean_absolute_error: 0.0537
# Epoch 51/80
# 30/30 [==============================] - 2s 55ms/step - loss: 2.0133e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0033 - val_mean_absolute_error: 0.0422
# Epoch 52/80
# 30/30 [==============================] - 2s 62ms/step - loss: 2.2264e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0071 - val_mean_absolute_error: 0.0675
# Epoch 53/80
# 30/30 [==============================] - 2s 61ms/step - loss: 2.0076e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0048 - val_mean_absolute_error: 0.0559
# Epoch 54/80
# 30/30 [==============================] - 2s 54ms/step - loss: 1.9377e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0046 - val_mean_absolute_error: 0.0537
# Epoch 55/80
# 30/30 [==============================] - 2s 53ms/step - loss: 2.0997e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0041 - val_mean_absolute_error: 0.0500
# Epoch 56/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.8686e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0016 - val_mean_absolute_error: 0.0303
# Epoch 57/80
# 30/30 [==============================] - 2s 66ms/step - loss: 1.8930e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0038 - val_mean_absolute_error: 0.0485
# Epoch 58/80
# 30/30 [==============================] - 2s 62ms/step - loss: 1.7676e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0029 - val_mean_absolute_error: 0.0411
# Epoch 59/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.8709e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0028 - val_mean_absolute_error: 0.0394
# Epoch 60/80
# 30/30 [==============================] - 2s 59ms/step - loss: 1.7167e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0039 - val_mean_absolute_error: 0.0472
# Epoch 61/80
# 30/30 [==============================] - 2s 61ms/step - loss: 1.9112e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0030 - val_mean_absolute_error: 0.0418
# Epoch 62/80
# 30/30 [==============================] - 2s 68ms/step - loss: 1.6153e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0039 - val_mean_absolute_error: 0.0490
# Epoch 63/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.6690e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0048 - val_mean_absolute_error: 0.0559
# Epoch 64/80
# 30/30 [==============================] - 2s 68ms/step - loss: 1.6904e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0037 - val_mean_absolute_error: 0.0488
# Epoch 65/80
# 30/30 [==============================] - 2s 61ms/step - loss: 1.5482e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0032 - val_mean_absolute_error: 0.0436
# Epoch 66/80
# 30/30 [==============================] - 2s 61ms/step - loss: 2.0010e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0091 - val_mean_absolute_error: 0.0821
# Epoch 67/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.8251e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0049 - val_mean_absolute_error: 0.0582
# Epoch 68/80
# 30/30 [==============================] - 2s 59ms/step - loss: 1.5765e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0021 - val_mean_absolute_error: 0.0346
# Epoch 69/80
# 30/30 [==============================] - 2s 55ms/step - loss: 1.4979e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0035 - val_mean_absolute_error: 0.0481
# Epoch 70/80
# 30/30 [==============================] - 2s 66ms/step - loss: 1.4581e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0022 - val_mean_absolute_error: 0.0354
# Epoch 71/80
# 30/30 [==============================] - 2s 70ms/step - loss: 1.5144e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0023 - val_mean_absolute_error: 0.0372
# Epoch 72/80
# 30/30 [==============================] - 2s 56ms/step - loss: 1.7117e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0034 - val_mean_absolute_error: 0.0457
# Epoch 73/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.5163e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0047 - val_mean_absolute_error: 0.0576
# Epoch 74/80
# 30/30 [==============================] - 2s 59ms/step - loss: 1.4807e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0033 - val_mean_absolute_error: 0.0483
# Epoch 75/80
# 30/30 [==============================] - 2s 61ms/step - loss: 1.4216e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0047 - val_mean_absolute_error: 0.0577
# Epoch 76/80
# 30/30 [==============================] - 2s 62ms/step - loss: 1.4372e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0027 - val_mean_absolute_error: 0.0400
# Epoch 77/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.6123e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0020 - val_mean_absolute_error: 0.0343
# Epoch 78/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.4441e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0032 - val_mean_absolute_error: 0.0446
# Epoch 79/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.5014e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0054 - val_mean_absolute_error: 0.0622
# Epoch 80/80
# 30/30 [==============================] - 2s 59ms/step - loss: 1.4791e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0033 - val_mean_absolute_error: 0.0476

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 20ms/step
# array([[0.47622922, 0.47531122],
#        [0.48182908, 0.48136503],
#        [0.48729098, 0.4871902 ],
#        [0.50234807, 0.5016543 ],
#        [0.51186293, 0.5116646 ]], dtype=float32)

# %%
# Inversing scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1553.8909, 1549.1733],
#        [1564.2725, 1560.3931],
#        [1574.3986, 1571.1891],
#        [1602.3131, 1597.9961],
#        [1619.9529, 1616.5486]], dtype=float32)

# %% [markdown]
# ## Visualizing predicted and actual data

# %%
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
 # Inverse scaling
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']])

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1553.890869      1549.173340
# 2020-08-25  1582.07  1608.22     1564.272461      1560.393066
# 2020-08-26  1608.00  1652.38     1574.398560      1571.189087
# 2020-08-27  1653.68  1634.33     1602.313110      1597.996094
# 2020-08-28  1633.49  1644.41     1619.952881      1616.548584

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ## Predicting upcoming 10 days

# %%
# Creating a dataframe and adding 10 days to existing index 

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,
                                                index=pd.date_range(start=gs_slic_data.index[-1],
                                                                    periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2282.409668      2421.467773
# 2021-06-10  2494.01  2521.60     2295.436768      2440.004150
# 2021-06-11  2524.92  2513.93     2307.153076      2456.198242
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
